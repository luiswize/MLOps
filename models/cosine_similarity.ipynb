# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
testing_df = pd.read_csv('./testing-data.csv')

# %%
df = pd.read_csv('../complete_data.csv')
df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists              id_artists  \
# 0       126903         0              ['Uli']  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  ['Fernando Pessoa']  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  ['Ignacio Corsini']  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  ['Ignacio Corsini']  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      ['Dick Haymes']  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  instrumentalness  liveness  \
# ...

# %%
song_attributes_df = df[['id','danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'time_signature']]

# %%
features_df = song_attributes_df.select_dtypes(include=np.number)
features_df
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.645  0.4450    0   -13.338     1       0.4510         0.674
# 1              0.695  0.2630    0   -22.136     1       0.9570         0.797
# 2              0.434  0.1770    1   -21.180     1       0.0512         0.994
# 3              0.321  0.0946    7   -27.961     1       0.0504         0.995
# 4              0.402  0.1580    3   -16.900     0       0.0390         0.989
# ...              ...     ...  ...       ...   ...          ...           ...
# 586667         0.560  0.5180    0    -7.471     0       0.0292         0.785
# 586668         0.765  0.6630    0    -5.223     1       0.0652         0.141
# 586669         0.535  0.3140    7   -12.823     0       0.0408         0.895
# 586670         0.696  0.6150   10    -6.212     1       0.0345         0.206
# 586671         0.686  0.7230    6    -7.067     1       0.0363         0.105
#
# ...

# %%
test_playlist = pd.read_csv('./testing-data.csv')
test_song = test_playlist[test_playlist['track_id'] == '2pb0aDEgDJ3PfWW1clmvSS'].select_dtypes(include=np.number).drop(['duration_ms'], axis=1)
test_song
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 5         0.594   0.578    4   -10.676     0        0.034         0.679
#
#    instrumentalness  liveness  valence   tempo  time_signature
# 5             0.123     0.105    0.536  77.481               4

# %%
test_playlist[test_playlist['track_id'] == '2pb0aDEgDJ3PfWW1clmvSS']
# Out:
#           artist                       album track_name  \
# 5  León Larregui  Solstis - De León Larregui   Souvenir
#
#                  track_id  danceability  energy  key  loudness  mode  \
# 5  2pb0aDEgDJ3PfWW1clmvSS         0.594   0.578    4   -10.676     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence   tempo  \
# 5        0.034         0.679             0.123     0.105    0.536  77.481
#
#    duration_ms  time_signature  \
# 5       239120               4
#
#                                                  url
# 5  https://i.scdn.co/image/ab67616d00001e025be353...

# %%
# features_scaler = StandardScaler()
# test_song_scaler = StandardScaler()
# normalized_df =features_scaler.fit_transform(features_df)
# normalized_test_song =test_song_scaler.fit_transform(test_song)

# normalized_test_song.shape

# %%
similarity = cosine_similarity(features_df, test_song )
similarity_df = pd.DataFrame(similarity, columns=['cosine_similarity'])
similarity
# Out:
# array([[0.99829534],
#        [0.99480402],
#        [0.99861563],
#        ...,
#        [0.99848598],
#        [0.99584722],
#        [0.9970777 ]])

# %%
results = pd.concat([df, similarity_df], axis=1)
results
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
results.sort_values('cosine_similarity', ascending=False).head(20)
# Out:
#                             id  \
# 85702   68UIOPderAlQy5eb7K4iUO
# 414221  6ahtseat5fNASoEUcPi0d6
# 522672  4UoD6iXtDDHJVIonNEf1Qz
# 370463  4FkF0LNXcLXLmMAmycmTg5
# 322438  7hQIRV5QsojXS7aLmvJokt
# 28720   2c6KBMhRHdXYcOdLwsfFnC
# 207517  6T6UOUE6PwUG00T8ifLUU4
# 90052   4OBZT9EnhYIV17t4pGw7ig
# 90835   75TDPu9k7Yv3IovdYaNCwk
# 314245  587wHAbZGA4Gh172pPtibO
# 325633  21VsRiYImQkxt4dVD4utse
# 417921  3IwJmL7ztDQr2p46dH48lr
# 169222  2R5gWZgxwSXvoe2Lj6bOxo
# 270521  3lXCNDYH3ULcL2n45jkuY9
# 31669   6m8fzdK14sJldkat1CMUrZ
# 168030  5n2CqaJnI4CcTNJnS4Vzup
# 174794  7BsmNN7MYUelnZnabiHqR7
# 184756  3FRmjEcZJPxKcNkuphOby5
# 161510  3J4uo5ogPjGtCSoQrZ41hI
# 314007  0TBQzt8fM0MALUymeXTJOY
#
#                                                      name  popularity  \
# 85702                                            Souvenir          63
# 414221                                       C'EST SI BON          29
# 522672                                    Dil Ne Dhadkana          12
# ...
